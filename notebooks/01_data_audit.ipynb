# %% [markdown]
# # 01 - Data Audit
# Load the Online Retail II Excel file, standardize columns, and review data quality.

# %%
from src import config
from src.io import load_transactions_excel, audit_transactions, save_raw_parquet
from src.utils import ensure_dirs

ensure_dirs([config.PROCESSED_DIR])

df = load_transactions_excel()
audit_summary, metrics = audit_transactions(df)
audit_summary.head(), metrics
# Out:
# (             missing  missing_pct  n_unique
#  InvoiceNo          0         0.00     53628
#  StockCode          0         0.00      5305
#  Description     4382         0.41      5699
#  Quantity           0         0.00      1057
#  InvoiceDate        0         0.00     47635,
#  {'rows': 1067371,
#   'date_min': Timestamp('2009-12-01 07:45:00'),
#   'date_max': Timestamp('2011-12-09 12:50:00'),
#   'duplicate_rows': np.int64(12133),
#   'total_customers': 5942})

# %%
save_raw_parquet(df)
# Out:
# '/home/dhaka/Main Project/customer-churn-clv-online-retail-ii/data/processed/transactions_raw.parquet'
